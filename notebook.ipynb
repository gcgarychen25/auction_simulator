# %% [raw]
# # **Multi-Agent Real-Estate Auction Simulator**
#
# You can run the commands in this notebook or run the commands in the README.md file to run the project.
#
# ## 🏗️ **Project Overview**
#
# This project implements a sophisticated **multi-agent auction environment** for real-estate transactions, featuring:
#
# - **5 Distinct Buyer Personas**: Conservative, Aggressive, Analytical, Budget-Conscious, and FOMO
# - **Agent implementation from heuristic to RL to LLM**
# - **English Auction Format**: Ascending price mechanism with strategic bidding
# - **Comprehensive Analytics**: Economic efficiency metrics and behavioral analysis
# - **RL-Ready Architecture**: Gymnasium-compatible environment for reinforcement learning
#
# ## 🚀 **Three-Phase Development Roadmap**
#
# ### **Phase 0: Foundation & Validation** 🔍
# - **Purpose**: Smoke test and architecture validation
# - **Approach**: Single episode with heuristic agents
# - **Output**: Basic functionality demonstration
# - **Key Metrics**: Episode completion, action parsing, environment stability
#
# ### **Phase 1: Monte Carlo Baseline** 📊
# - **Purpose**: Establish statistical baseline with heuristic policies
# - **Approach**: Configurable episodes (50-1000+) with comprehensive analytics
# - **Output**: `reports/phase1_analysis.md` with efficiency metrics
# - **Key Metrics**: Allocative efficiency, revenue efficiency, persona performance
#
# ### **Phase 2: Reinforcement Learning** 🧠
# - **Purpose**: Train RL agents and compare against heuristic baseline
# - **Approach**: Configurable PPO training + evaluation episodes
# - **Output**: `reports/phase2_analysis.md` with RL vs heuristic comparison
# - **Key Metrics**: Allocative efficiency, revenue efficiency, price distribution
# - notes: did not tune the hyperparameters for RL agents, so the results are not optimal.
#
# ### **Phase 3: LLM Multi-Agent Simulation** 🤖
# - **Purpose**: Simulate complex, human-like negotiation and qualitative decision-making.
# - **Approach**: A multi-agent system where both Buyer and Seller agents are powered by LLMs (Gemini). Agents engage in a Q&A phase before each bidding round, allowing them to gather information and act strategically based on their unique personas and requirements defined in `config.yaml`.
# - **Output**: A detailed, human-readable transcript of the auction, including agent commentary, questions, and answers.
# - **Key Metrics**: N/A.
# - notes: realistic conversation between buyer and seller and the auction outcomes.
#
# ---
#
# **📈 Expected Evolution**: Heuristic baseline → RL learning → Strategic sophistication

# %%
# 🔧 PRECONDITION CHECKS
# Verify environment setup and dependencies

import os
import sys
from pathlib import Path

print("🔍 ENVIRONMENT VALIDATION")
print("=" * 50)

# Check Python environment
print(f"🐍 Python: {sys.version.split()[0]}")
print(f"📂 Working Directory: {os.getcwd()}")

# Check required files
required_files = ['config.yaml', 'run.py', 'auction_env.py']
for file in required_files:
    if Path(file).exists():
        print(f"✅ {file}: Found")
    else:
        print(f"❌ {file}: Missing")

# Check dependencies
try:
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    import gymnasium as gym
    import torch
    print("✅ Core Dependencies: Installed")
except ImportError as e:
    print(f"❌ Dependencies: Missing - {e}")

# Check LLM capability
gemini_key = os.getenv("GEMINI_API_KEY")
if gemini_key and gemini_key != "your_api_key_here":
    print(f"✅ Gemini API: Configured")
else:
    print("⚠️  Gemini API: Not configured (will use heuristic seller)")

# Create reports directory
Path("reports").mkdir(exist_ok=True)
print("✅ Reports Directory: Ready")

print("\n🎯 SYSTEM STATUS: Ready for phase execution")
print("💡 Tip: Each phase generates detailed reports in ./reports/")
# Out:
# 🔍 ENVIRONMENT VALIDATION
# ...
# 🐍 Python: 3.10.18
# 📂 Working Directory: /Users/garychen/Desktop/auction_simulator
# ✅ config.yaml: Found
# ✅ run.py: Found
# ✅ auction_env.py: Found
# ✅ Core Dependencies: Installed
# ✅ Gemini API: Configured
# ✅ Reports Directory: Ready
#
# 🎯 SYSTEM STATUS: Ready for phase execution
# 💡 Tip: Each phase generates detailed reports in ./reports/

# %%
# 🔁 Utility: Run Phase Command with Collapsible Output
from IPython.display import display, Markdown
import subprocess
import sys

def show_output(title, content):
    """Display collapsible output in notebook."""
    display(Markdown(f"<details><summary><b>{title}</b></summary>\n\n```\n{content}\n```</details>"))

def run_phase(phase_label, command_list, timeout=300, report_name=None):
    """Run a simulation phase with logging and collapsible output."""
    print(f"🚀 EXECUTING {phase_label}")
    print("=" * 60)
    try:
        result = subprocess.run(command_list, capture_output=True, text=True, timeout=timeout)

        show_output("📊 STDOUT", result.stdout)
        if result.stderr:
            show_output("⚠️ STDERR", result.stderr[-500:])

        if result.returncode == 0:
            print(f"\n✅ {phase_label} STATUS: SUCCESS")
            if report_name:
                print(f"📄 Report: {report_name}")
        else:
            print(f"\n❌ {phase_label} STATUS: FAILED (code {result.returncode})")

    except subprocess.TimeoutExpired:
        print(f"⏰ TIMEOUT: {phase_label} took too long")
    except Exception as e:
        print(f"💥 ERROR in {phase_label}: {e}")

# %%
run_phase("Phase 0: Smoke Test", [sys.executable, "run.py", "--phase", "0"], timeout=30)
# Out:
# 🚀 EXECUTING Phase 0: Smoke Test
# ...
# <details><summary><b>📊 STDOUT</b></summary>
#
# ```
# ✅ Environment variables loaded from .env file
# ╭────────────────────────────────── Welcome ───────────────────────────────────╮
# │                              Auction Simulator                               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# 📝 All detailed logs are being saved to auction.log
#
# ...
# 🚀 Starting New Simulation Run: Phase 0
# ...
# 🚀 Running Phase 0: Legacy Simulator Smoke Test...
#
# ```</details>
# <details><summary><b>⚠️ STDERR</b></summary>
#
# ```
# ===================================================🏁
# 🏆                    AUCTION COMPLETE                    🏆
# 🏁==========================================================🏁
# ✅ RESULT: SOLD for $11,500
# 🏆 WINNER: B3_ANALYTICAL_BUYER
# 💰 SELLER SURPLUS: $1,700
# 🛒 WINNER SURPLUS: $2,500
# 📊 SURPLUS EFFICIENCY: 100.0%
# 📈 PRICE PREMIUM OVER RESERVE: +17.3%
# ...

# %%
run_phase(
    "Phase 1: Monte Carlo Heuristic Agents",
    [sys.executable, "run.py", "--phase", "1", "--episodes", "10000", "--output", "phase1_results.csv"],
    timeout=600,
    report_name="reports/phase1_analysis.md"
)
# Out:
# 🚀 EXECUTING Phase 1: Monte Carlo
# ...
# <details><summary><b>📊 STDOUT</b></summary>
#
# ```
# ✅ Environment variables loaded from .env file
# ╭────────────────────────────────── Welcome ───────────────────────────────────╮
# │                              Auction Simulator                               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# 📝 All detailed logs are being saved to auction.log
#
# ...
# 🚀 Starting New Simulation Run: Phase 1
# ...
# 🚀 Running Phase 1: Monte Carlo Simulation (10000 episodes)...
# Running 10000 episodes with heuristic policies...
# Episode 0/10000 (elapsed: 0.0s)
# Episode 50/10000 (elapsed: 0.0s)
# Episode 100/10000 (elapsed: 0.1s)
# Episode 150/10000 (elapsed: 0.1s)
# Episode 200/10000 (elapsed: 0.1s)
# Episode 250/10000 (elapsed: 0.2s)
# Episode 300/10000 (elapsed: 0.2s)
# Episode 350/10000 (elapsed: 0.3s)
# Episode 400/10000 (elapsed: 0.3s)
# Episode 450/10000 (elapsed: 0.3s)
# Episode 500/10000 (elapsed: 0.4s)
# ...

# %%
run_phase(
    "Phase 2: RL trained agents",
    [sys.executable, "run.py", "--phase", "2", "--episodes", "200", "--training-steps", "1000", "--output", "phase2_results.csv"],
    timeout=1800,
    report_name="reports/phase2_analysis.md"
)
# Out:
# 🚀 EXECUTING Phase 2: Reinforcement Learning
# ...
# <details><summary><b>📊 STDOUT</b></summary>
#
# ```
# ✅ Environment variables loaded from .env file
# ╭────────────────────────────────── Welcome ───────────────────────────────────╮
# │                              Auction Simulator                               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# 📝 All detailed logs are being saved to auction.log
#
# ...
# 🚀 Starting New Simulation Run: Phase 2
# ...
# 🚀 Running Phase 2: RL Training and Evaluation...
# ...
# 🤖 STARTING PHASE 2: RL AGENT TRAINING & EVALUATION 🤖
# ...
#
# --- 🏋️ TRAINING FOR 1000 EPISODES (with opponent randomization) ---
# --- Training episode 100/1000 complete ---
# --- Training episode 200/1000 complete ---
# --- Training episode 300/1000 complete ---
# --- Training episode 400/1000 complete ---
# --- Training episode 500/1000 complete ---
# --- Training episode 600/1000 complete ---
# --- Training episode 700/1000 complete ---
# ...

# %%
run_phase("Phase 3: LLM Multi-Agent Simulation", [sys.executable, "run.py", "--phase", "3"], timeout=300)
# Out:
# 🚀 EXECUTING Phase 3: LLM Multi-Agent Simulation
# ...
# <details><summary><b>📊 STDOUT</b></summary>
#
# ```
# ✅ Environment variables loaded from .env file
# ╭────────────────────────────────── Welcome ───────────────────────────────────╮
# │                              Auction Simulator                               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# 📝 All detailed logs are being saved to auction.log
#
# ...
# 🚀 Starting New Simulation Run: Phase 3
# ...
# 🚀 Running Phase 3: LLM Multi-Agent Simulation...
# --- 🚀 Starting New Auction Episode 🚀 ---
# This is Round 0 of a real estate auction.
# Current Price: $8,000.00
# Leading Bidder: None
# Active Buyers (5): B1_CONSERVATIVE_INVESTOR, B2_AGGRESSIVE_TRADER, B3_ANALYTICAL_BUYER, B4_BUDGET_CONSCIOUS, B5_FOMO_BIDDER
# ---
# Recent History:
#
#
# --- Round 1 ---
# --- Phase: Q&A ---
# ...

# %% [raw]
# ## 📊 **Report Guide**
#
# Each phase generates detailed analytical reports for more information.
#
# Phase 1 Report at phase1_report.md
# Phase 2 report at phase2_rl_report.md
